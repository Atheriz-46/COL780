# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
with open('token.txt','r') as f:
  username,repository,git_token = f.read().split('\n')
# Out:
# /content/drive/MyDrive/Github

# %%
#uncomment to clone
# !git clone https://{git_token}@github.com/{username}/{repository}
# %cd {repository}
# !ls -a
# Out:
# Cloning into 'COL780'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 196 (delta 82), reused 151 (delta 45), pack-reused 0
# Receiving objects: 100% (196/196), 1.03 MiB | 11.82 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# /content/drive/My Drive/Github/COL780
# A1  A2	A3  .git  .gitignore  LICENSE  P1  README.md

# %%
##use to commit
# !git config --global user.email "abc"
# !git commit -m "Repo is ready for colab"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
